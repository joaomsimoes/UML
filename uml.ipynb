# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests

r = 'https://api-pub.bitfinex.com/v2/book/tBTCUSD/P2'

response = requests.get(r, params={'len': 100})
df = pd.DataFrame(response.json(), columns=['price', 'count', 'amount'])
df
# Out:
#      price  count      amount
# 0    29700     81   22.895393
# 1    29600    107  206.969994
# 2    29500     60  153.419960
# 3    29400     42   23.499242
# 4    29300     33   16.447929
# ..     ...    ...         ...
# 195  39300     18   -0.820046
# 196  39400     17   -0.414756
# 197  39500     32   -0.333169
# 198  39600     27   -1.099529
# 199  39700     24   -3.597595
#
# [200 rows x 3 columns]

# %%
bid = df[df['amount'] > 0]
ask = df[df['amount'] < 0]

# %%
sns.scatterplot(y=bid['price'], x=bid['amount'], size=bid['count'])
# Out:
# <AxesSubplot:xlabel='amount', ylabel='price'>

# %%
sns.scatterplot(y=ask['price'], x=ask['amount'], size=ask['count'])
# Out:
# <AxesSubplot:xlabel='amount', ylabel='price'>
